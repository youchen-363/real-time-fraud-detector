# %%
import joblib
from xgboost import XGBClassifier
import numpy as np
import pandas as pd

# %%
df = pd.read_parquet('../../data/grouped_data_with_nameOrig_Dest.parquet')

# %%
df[(df['isFraud'] == 1) & (df['type_CASH_IN'] == 1)].head()
# Out:
# Empty DataFrame
# Columns: [amount, nameOrig, nameDest, isFraud, type_CASH_IN, type_CASH_OUT, type_DEBIT, type_PAYMENT, type_TRANSFER, orig_tx_count_same_step, orig_tx_cumcount, orig_prev_amount, orig_amount_ratio, steps_since_last_tx, dest_tx_cumcount, dest_prev_amount, dest_amount_ratio, dest_steps_since_last, pair_tx_cumcount, is_new_dest, pair_total_amount, hour_of_day, day, is_night]
# Index: []
#
# [0 rows x 24 columns]

# %%
model = XGBClassifier()
model.load_model('../../model/xgboost.json')
print(model.predict(ml_txn)[0])
# Out:
# 0
